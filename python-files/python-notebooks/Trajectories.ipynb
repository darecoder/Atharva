# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from geopandas import GeoDataFrame
import movingpandas as mpd
import io

# %%
data = pd.read_csv('20200802125133.csv', comment='#')
main_gdf = gpd.read_file('Demographics_of_India.dbf')

# %%
data['latitude'] = data['Lat(deg)']
data['longitude'] = data['Long(deg)']

# %%
geometry = [Point(xy) for xy in zip(data.longitude, data.latitude)]
crs = {'init': 'epsg:4326'}
data_gdf = GeoDataFrame(data, crs=crs, geometry=geometry)

# %%
data.head()

# %%
toy_traj = mpd.Trajectory(data_gdf, 1)

# %%
base_map = main_gdf.plot(figsize=(15, 10))
toy_traj.plot(ax=base_map, color='orange')

# %%
header = '#Year,Month,Day,Hour,Minute,Lat(deg),Long(deg),Height(m agl),PBLH(m),U(m/s),V(m/s),W(m/s),T(K),P(Pa)'

# %%
f = open('20200802125133.csv', 'r')

lines = f.readlines()

all = []
temp = ''
for line in lines:
    if line.startswith('#Year'):
        all.append(temp)
        temp = ''
        line = line[1:]
        
    temp += line
print("asdsad")

df_list =  []
for element in all:
    try:
        df_list.append(pd.read_csv(io.StringIO(element), comment='#', index_col=0))
    except Exception as e:
        pass

traj_list = []
gdf_list = []
for i,data in enumerate(df_list):
    data['latitude'] = data['Lat(deg)']
    data['longitude'] = data['Long(deg)']
    try:
        geometry = [Point(xy) for xy in zip(data.longitude, data.latitude)]
        crs = {'init': 'epsg:4326'}
        data_gdf = GeoDataFrame(data, crs=from_epsg(31256), geometry=geometry)
        gdf_list.append(data_gdf)
#         print(data_gdf)
        traj_list.append(mpd.Trajectory(data_gdf, 1))
    except Exception as e:
        print(e)
        pass
# Out:
# asdsad
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
f2 = open('20200802132632.csv', 'r')

lines2 = f.readlines()

all2 = []
temp2 = ''
for line2 in lines:
    if line2.startswith('#Year'):
        all2.append(temp)
        temp2 = ''
        line2 = line[1:]
        
    temp2 += line2
print("asdsad")

df_list2 =  []
for element2 in all:
    try:
        df_list2.append(pd.read_csv(io.StringIO(element2), comment='#', index_col=0))
    except Exception as e:
        pass

traj_list2 = []
gdf_list2 = []
for i,data2 in enumerate(df_list2):
    data2['latitude'] = data2['Lat(deg)']
    data2['longitude'] = data2['Long(deg)']
    try:
        geometry2 = [Point(xy) for xy in zip(data2.longitude, data2.latitude)]
        crs = {'init': 'epsg:4326'}
        data_gdf2 = GeoDataFrame(data2, crs=from_epsg(31256), geometry=geometry2)
        gdf_list2.append(data_gdf2)
#         print(data_gdf)
        traj_list2.append(mpd.Trajectory(data_gdf2, 1))
    except Exception as e:
        print(e)
        pass
# Out:
# asdsad
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
from matplotlib import pyplot as plt
plt = plt.figure()
base_map = main_gdf.plot(figsize=(30, 30))
# for traj in traj_list:
#     try:
#         traj.plot(ax=base_map, color='orange')
#     except Exception as e:
#         print("ERROR", e)
for traj in gdf_list[:20]:
    try:
        traj.plot(ax=base_map, color='purple', markersize=1, linestyle='dashed')
    except Exception as e:
        print("ERROR", e)
jan_gdf.plot(ax=base_map, column='mean_tropospheric_NO2_column_number_density', color='red')
# feb_gdf.plot(ax=base_map, column='mean_tropospheric_NO2_column_number_density', color='yellow')
# for traj in gdf_list2[:20]:
#     try:
#         traj.plot(ax=base_map, color='red', markersize=1, linestyle='dashed')
#     except Exception as e:
#         print("ERROR", e)
# Out:
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/geopandas/plotting.py:572: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <AxesSubplot:>

# %% [markdown]
# ##### traj_list

# %%
traj_list[5].plot()

# %%
mo = pd.read_csv('20200802125133.csv', comment='#',)

# %%
mo = mo[:1000]

# %%
mo['latitude'] = mo['Lat(deg)']
mo['longitude'] = mo['Long(deg)']
geometry = [Point(xy) for xy in zip(mo.longitude, mo.latitude)]
crs = {'init': 'epsg:31256'}
data_gdf = GeoDataFrame(mo, crs=from_epsg(31256), geometry=geometry)

# %%
t = mpd.Trajectory(data_gdf, 1)
base_map = main_gdf.plot(figsize=(15, 10))
t.plot(ax=base_map, color='orange')
jan_gdf.plot(ax=base_map, column='mean_tropospheric_NO2_column_number_density', color='red')
feb_gdf.plot(ax=base_map, column='mean_tropospheric_NO2_column_number_density', color='yellow')
# Out:
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/geopandas/plotting.py:572: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/geopandas/plotting.py:572: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   warnings.warn(
# <AxesSubplot:>

# %%
jan = pd.read_csv('jan_spots.csv')

geometry = [Point(xy) for xy in zip(jan.longitude, jan.latitude)]
crs = {'init': 'epsg:31256'}
jan_gdf = GeoDataFrame(jan, crs=from_epsg(31256), geometry=geometry)
# Out:
# /home/stark/miniconda3/envs/pysal/lib/python3.8/site-packages/pyproj/crs/crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
feb = pd.read_csv('feb_spots.csv')

geometry = [Point(xy) for xy in zip(feb.longitude, feb.latitude)]
crs = {'init': 'epsg:31256'}
feb_gdf = GeoDataFrame(feb
                       , crs=from_epsg(31256), geometry=geometry)
